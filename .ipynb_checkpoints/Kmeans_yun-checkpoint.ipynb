# %%
# coding: utf-8
import numpy as np
import cv2
import argparse
import sys
from PIL import Image
from sklearn import preprocessing
from sklearn.metrics.pairwise import euclidean_distances
import matplotlib.pyplot as plt
import os,sys
from os import listdir
from os.path import isfile, join
import time as t
import csv
import matplotlib.pyplot as plt
import math
import easydict

# %%
##############################################################################
#Define parameters
#parser = argparse.ArgumentParser()
#parser.add_argument('--cluster', type=int, default=10)
#parser.add_argument('--threshold', type=float, default=1E-4)
#parser.add_argument('--input', type=str, default="/Users/yunliang/Dropbox (UFL)/BME6938/Mini_project1_yun/img/1_00062_sub0_007.png")
#parser.add_argument('--iter', type=int, default=20)
#args = parser.parse_args()
args = easydict.EasyDict({
    "cluster": 10,
    "threshold": 1e-4,
    "input": "/Users/yunliang/Dropbox (UFL)/BME6938/Mini_project1_yun/img/1_00062_sub0_007.png",
    "iter": 20
})

K = args.cluster
threshold = args.threshold
useType = np.float
seg_img = []
dice = []
time_cost = []

# %%
##############################################################################
#Dice coefficient
def dice_coefficient(a,b):
    #import pdb;pdb.set_trace()
    #a_bigram_list = [a[i:i+2] for i in range(len(a)-1)]
    #b_bigram_list = [b[i:i+2] for i in range(len(b)-1)]
    a_bigram_list = a
    b_bigram_list = b
    # assignments to save function calls
    lena = len(a_bigram_list)
    lenb = len(b_bigram_list)
    # initialize match counters
    matches = i = j = 0
    while (i < lena and j < lenb):
        if a_bigram_list[i] == b_bigram_list[j]:
            matches += 2
            i += 1
            j += 1
        elif a_bigram_list[i] < b_bigram_list[j]:
            i += 1
        else:
            j += 1
    #import pdb;pdb.set_trace()
    score = float(matches)/float(lena + lenb)
    return score

# %%
##############################################################################
#Ecucidean distance
def eudis5(v1, v2):
    dist = [(a - b)**2 for a, b in zip(v1, v2)]
    dist = math.sqrt(sum(dist))
    return dist

# %%
##############################################################################
#Find center of the selected pixels
def findCentroids(feats, centroids):
    #import pdb;pdb.set_trace()
    N = feats.shape[0]
    #provide each feature(3 dimension) with one id
    idx = np.zeros((N), dtype=np.int)
    for i in range(N):
        bestIdx = -1
        bestDist = -1
        for j in range(K):
            #Euclidean distance be calculated
            #dist = np.linalg.norm(feats[i] - centroids[j])
            dist = eudis5(feats[i],centroids[j])
            if (bestIdx == -1 or dist < bestDist):
                bestIdx = j
                bestDist = dist
        idx[i] = bestIdx
    return idx

# %%
##############################################################################
#Ecucidean distance
def eudis5(v1, v2):
    dist = [(a - b)**2 for a, b in zip(v1, v2)]
    dist = math.sqrt(sum(dist))
    return dist

# %%
##############################################################################
#main function
if __name__ == '__main__':
    proj_path = os.getcwd()
    mypath = os.path.join(proj_path,'img')
    onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    save_path = os.path.join(proj_path,'img_res_kmeans')
    if not os.path.exists(save_path):
        os.makedirs(save_path)
    for inputName in onlyfiles:
        #import pdb;pdb.set_trace()
        print('Processing image: ',inputName)
        filename, file_extension = os.path.splitext(inputName)
        outputName = filename + '_output.png'
        img = cv2.imread(os.path.join(mypath,inputName))
        img_ori = cv2.imread(os.path.join(mypath,inputName))

        if img is not None:
            start = t.time()
            size = (img.shape[0] * img.shape[1], img.shape[2])
            feats = np.reshape(img, size).astype(useType) / 256.0

            centroids = np.random.rand(K, img.shape[2]).astype(useType)
            newCentroids = np.zeros((K, img.shape[2]), dtype=useType)
            ITER = 1
            N = size[0]
            #print ('Number of Features:', N)
            print ('Number of Clusters:', K)
            #import pdb;pdb.set_trace()
            while (True):
                idx = findCentroids(feats, centroids)
                for i in range(K):
                    tmp = feats[idx == i]
                    if len(tmp) == 0 or (tmp is None):
                        tmp = centroids[i].copy()
                    newCentroids[i] = np.mean(tmp, axis=0)

                error = 0.0
                for i in range(K):
                    #error = error + np.linalg.norm(newCentroids[i] - centroids[i])
                    error = error + eudis5(newCentroids[i],centroids[i])
                print ('ITERATION:', ITER, 'Error Rate:', error)
                ITER = ITER + 1
                if (error < threshold):
                    break
                centroids = newCentroids.copy()
                if (ITER > args.iter):
                    break

            idx = findCentroids(feats, centroids)
            centroids = centroids * 256.0
            idx = np.reshape(idx, (img.shape[0], img.shape[1]))
            for i in range(img.shape[0]):
                for j in range(img.shape[1]):
                    pix = centroids[idx[i][j]]
                    img[i][j] = pix
            #change img to [0,255]
            #import pdb;pdb.set_trace()
            '''
            plt.imshow(img_ori)            
            plt.show()
            plt.imshow(img)
            plt.show()
            '''
            img = (img-np.amin(img))/(np.amax(img)-np.amin(img))*255.0
            img = img.astype(np.uint8)
            #import pdb;pdb.set_trace()
            end = t.time()
            #calculate time and dice coeficient
            print("Time taken: " + str((end - start)/60) + " min")
            a = img_ori.reshape(img.shape[0] * img.shape[1]* img.shape[2],1)
            b = img.reshape(img.shape[0] * img.shape[1]* img.shape[2],1)
            dice_dist = dice_coefficient(a,b)
            dice.append(dice_dist)
            print ('Dice similarity score is {}'.format(dice_dist))
            time_cost.append(float(str((end - start)/60)))
            cv2.imwrite(os.path.join(save_path,outputName), img)
# Out:
# Processing image:  118421_009.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 2.8979043471151265
# ITERATION: 2 Error Rate: 0.8152673920554547
# ITERATION: 3 Error Rate: 0.3881416151274202
# ITERATION: 4 Error Rate: 0.1966872325818656
# ITERATION: 5 Error Rate: 0.134087940693111
# ITERATION: 6 Error Rate: 0.10373529853702773
# ITERATION: 7 Error Rate: 0.08949966034313982
# ITERATION: 8 Error Rate: 0.0776616076339498
# ITERATION: 9 Error Rate: 0.06326383264088292
# ITERATION: 10 Error Rate: 0.05108495522500324
# ITERATION: 11 Error Rate: 0.04134532581719752
# ITERATION: 12 Error Rate: 0.03436878293596485
# ITERATION: 13 Error Rate: 0.027945724897552225
# ITERATION: 14 Error Rate: 0.024344072713534153
# ITERATION: 15 Error Rate: 0.022121518682138918
# ITERATION: 16 Error Rate: 0.02125037339924081
# ITERATION: 17 Error Rate: 0.02057931409177299
# ITERATION: 18 Error Rate: 0.019514608386960217
# ITERATION: 19 Error Rate: 0.018871992317794028
# ITERATION: 20 Error Rate: 0.017618227555155665
# Time taken: 4.248573378721873 min
# Dice similarity score is 0.0008341471354166666
# Processing image:  118279_002.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 2.659125225102992
# ITERATION: 2 Error Rate: 0.7443191404127266
# ITERATION: 3 Error Rate: 0.4166984551517928
# ITERATION: 4 Error Rate: 0.24352798128770442
# ITERATION: 5 Error Rate: 0.1760478581446317
# ITERATION: 6 Error Rate: 0.15129272591155044
# ITERATION: 7 Error Rate: 0.12125805954814341
# ITERATION: 8 Error Rate: 0.09007458950742331
# ITERATION: 9 Error Rate: 0.07349487090357479
# ITERATION: 10 Error Rate: 0.06665033388082542
# ITERATION: 11 Error Rate: 0.062866086759995
# ITERATION: 12 Error Rate: 0.0588126002122737
# ITERATION: 13 Error Rate: 0.05479003080308194
# ITERATION: 14 Error Rate: 0.05196489598708483
# ITERATION: 15 Error Rate: 0.05117432105483262
# ITERATION: 16 Error Rate: 0.047867338037553775
# ITERATION: 17 Error Rate: 0.0457439401804308
# ITERATION: 18 Error Rate: 0.04472511587553897
# ITERATION: 19 Error Rate: 0.042549370994991106
# ITERATION: 20 Error Rate: 0.04066087961422892
# Time taken: 4.967865999539693 min
# Dice similarity score is 4.9591064453125e-05
# Processing image:  115924_010.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 2.7858675494236294
# ITERATION: 2 Error Rate: 0.936140364439797
# ITERATION: 3 Error Rate: 0.4788873280766111
# ITERATION: 4 Error Rate: 0.17656670630309548
# ITERATION: 5 Error Rate: 0.1176604708689291
# ITERATION: 6 Error Rate: 0.10301263758496651
# ITERATION: 7 Error Rate: 0.10547651192707792
# ITERATION: 8 Error Rate: 0.10633465250373823
# ITERATION: 9 Error Rate: 0.10832246587929029
# ITERATION: 10 Error Rate: 0.11401830529464294
# ITERATION: 11 Error Rate: 0.10212589095632443
# ITERATION: 12 Error Rate: 0.0727869735493936
# ITERATION: 13 Error Rate: 0.056567381851796945
# ITERATION: 14 Error Rate: 0.050454723660841826
# ITERATION: 15 Error Rate: 0.04763707334420805
# ITERATION: 16 Error Rate: 0.044160573562887474
# ITERATION: 17 Error Rate: 0.04029594097923148
# ITERATION: 18 Error Rate: 0.03561125768051172
# ITERATION: 19 Error Rate: 0.02968670195061879
# ITERATION: 20 Error Rate: 0.026290525786201332
# Time taken: 4.709040002028147 min
# Dice similarity score is 0.0019683837890625
# Processing image:  118336_011.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 2.318340291338453
# ITERATION: 2 Error Rate: 0.6053707273798842
# ITERATION: 3 Error Rate: 0.38462245086973657
# ITERATION: 4 Error Rate: 0.28045257107087146
# ITERATION: 5 Error Rate: 0.21805932559772911
# ITERATION: 6 Error Rate: 0.15274655660607755
# ITERATION: 7 Error Rate: 0.08603076416134146
# ITERATION: 8 Error Rate: 0.04792808270366252
# ITERATION: 9 Error Rate: 0.029144321737262373
# ITERATION: 10 Error Rate: 0.02242742750836515
# ITERATION: 11 Error Rate: 0.01943296083743504
# ITERATION: 12 Error Rate: 0.017715115679746568
# ITERATION: 13 Error Rate: 0.016910897686461788
# ITERATION: 14 Error Rate: 0.017130387099348745
# ITERATION: 15 Error Rate: 0.01756791870393541
# ITERATION: 16 Error Rate: 0.0181005779273774
# ITERATION: 17 Error Rate: 0.01816356156964631
# ITERATION: 18 Error Rate: 0.018364371061577116
# ITERATION: 19 Error Rate: 0.01829140784654631
# ITERATION: 20 Error Rate: 0.017653633456579103
# Time taken: 4.07011308670044 min
# Dice similarity score is 0.0002454121907552083
# Processing image:  118202_001.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 2.6357176814544863
# ITERATION: 2 Error Rate: 0.6957069906426814
# ITERATION: 3 Error Rate: 0.3147719568713245
# ITERATION: 4 Error Rate: 0.20254467511149746
# ITERATION: 5 Error Rate: 0.14564098280158908
# ITERATION: 6 Error Rate: 0.11238726211057774
# ITERATION: 7 Error Rate: 0.0953409364235403
# ITERATION: 8 Error Rate: 0.089720076799797
# ITERATION: 9 Error Rate: 0.08124747673997586
# ITERATION: 10 Error Rate: 0.06996078700607626
# ITERATION: 11 Error Rate: 0.05533482476141719
# ITERATION: 12 Error Rate: 0.044696833692666325
# ITERATION: 13 Error Rate: 0.03707935800097341
# ITERATION: 14 Error Rate: 0.031110216631424818
# ITERATION: 15 Error Rate: 0.027126474512844473
# ITERATION: 16 Error Rate: 0.024090197426967223
# ITERATION: 17 Error Rate: 0.021982747436219856
# ITERATION: 18 Error Rate: 0.019889770793228016
# ITERATION: 19 Error Rate: 0.018829487656740612
# ITERATION: 20 Error Rate: 0.018420645707712843
# Time taken: 3.3209182182947794 min
# Dice similarity score is 0.0016034444173177083
# Processing image:  118294_000.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 4.02934615972199
# ITERATION: 2 Error Rate: 0.9155705845020187
# ITERATION: 3 Error Rate: 0.3543952790968698
# ITERATION: 4 Error Rate: 0.16226436873506597
# ITERATION: 5 Error Rate: 0.08116044365757967
# ITERATION: 6 Error Rate: 0.052654751216403374
# ITERATION: 7 Error Rate: 0.037958671604331626
# ITERATION: 8 Error Rate: 0.029346312219489135
# ITERATION: 9 Error Rate: 0.02392320895764615
# ITERATION: 10 Error Rate: 0.020367278485005275
# ITERATION: 11 Error Rate: 0.017733399969997073
# ITERATION: 12 Error Rate: 0.015272011107893047
# ITERATION: 13 Error Rate: 0.013072023542989126
# ITERATION: 14 Error Rate: 0.011161645399839363
# ITERATION: 15 Error Rate: 0.009424246631491575
# ITERATION: 16 Error Rate: 0.008854008079611557
# ITERATION: 17 Error Rate: 0.007589386780892036
# ITERATION: 18 Error Rate: 0.006472905000780924
# ITERATION: 19 Error Rate: 0.005736893111024388
# ITERATION: 20 Error Rate: 0.00491749937651518
# Time taken: 3.8154879649480185 min
# Dice similarity score is 0.00267791748046875
# Processing image:  116916_014.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 3.070344576352843
# ITERATION: 2 Error Rate: 0.5758844372802541
# ITERATION: 3 Error Rate: 0.31699481607086344
# ITERATION: 4 Error Rate: 0.22235716451605742
# ITERATION: 5 Error Rate: 0.16118379679831293
# ITERATION: 6 Error Rate: 0.09047899669115714
# ITERATION: 7 Error Rate: 0.04685336116760364
# ITERATION: 8 Error Rate: 0.03280307325351953
# ITERATION: 9 Error Rate: 0.026792433115465187
# ITERATION: 10 Error Rate: 0.02456170415632905
# ITERATION: 11 Error Rate: 0.02318667374814111
# ITERATION: 12 Error Rate: 0.02204899931307351
# ITERATION: 13 Error Rate: 0.021739898356652847
# ITERATION: 14 Error Rate: 0.022406769636581746
# ITERATION: 15 Error Rate: 0.022773769530227736
# ITERATION: 16 Error Rate: 0.022624297148660127
# ITERATION: 17 Error Rate: 0.02240492779665343
# ITERATION: 18 Error Rate: 0.022193819504862218
# ITERATION: 19 Error Rate: 0.02205010315357816
# ITERATION: 20 Error Rate: 0.022133575762763737
# Time taken: 4.319017497698466 min
# Dice similarity score is 0.0016377766927083333
# Processing image:  118294_001.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 3.4492325369172443
# ITERATION: 2 Error Rate: 0.6698339963321651
# ITERATION: 3 Error Rate: 0.35817308739704096
# ITERATION: 4 Error Rate: 0.21455867944500148
# ITERATION: 5 Error Rate: 0.11340037021128649
# ITERATION: 6 Error Rate: 0.07016675456009025
# ITERATION: 7 Error Rate: 0.052943445588563225
# ITERATION: 8 Error Rate: 0.0445831581233002
# ITERATION: 9 Error Rate: 0.04396463222193589
# ITERATION: 10 Error Rate: 0.052347102651569354
# ITERATION: 11 Error Rate: 0.059342183070509896
# ITERATION: 12 Error Rate: 0.056488160976901375
# ITERATION: 13 Error Rate: 0.04803844178286954
# ITERATION: 14 Error Rate: 0.04242020073630922
# ITERATION: 15 Error Rate: 0.03865496533119937
# ITERATION: 16 Error Rate: 0.03491436896697294
# ITERATION: 17 Error Rate: 0.030640492655280547
# ITERATION: 18 Error Rate: 0.02608483824797546
# ITERATION: 19 Error Rate: 0.02107193046975886
# ITERATION: 20 Error Rate: 0.017635358955669058
# Time taken: 4.040752812226613 min
# Dice similarity score is 0.0009396870930989584
# Processing image:  118279_001.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 3.0104825307729226
# ITERATION: 2 Error Rate: 0.7751989126803503
# ITERATION: 3 Error Rate: 0.4572885229992113
# ITERATION: 4 Error Rate: 0.1756769758877194
# ITERATION: 5 Error Rate: 0.1289760213451406
# ITERATION: 6 Error Rate: 0.11820955499306005
# ITERATION: 7 Error Rate: 0.11673712216922788
# ITERATION: 8 Error Rate: 0.11139790788573914
# ITERATION: 9 Error Rate: 0.09304907235988603
# ITERATION: 10 Error Rate: 0.06836046046814562
# ITERATION: 11 Error Rate: 0.054566418742880395
# ITERATION: 12 Error Rate: 0.04806412640932695
# ITERATION: 13 Error Rate: 0.0429142556315219
# ITERATION: 14 Error Rate: 0.03825070147990044
# ITERATION: 15 Error Rate: 0.034236531180655304
# ITERATION: 16 Error Rate: 0.02999312704094069
# ITERATION: 17 Error Rate: 0.027288611603666045
# ITERATION: 18 Error Rate: 0.02476662525647366
# ITERATION: 19 Error Rate: 0.02254006675350965
# ITERATION: 20 Error Rate: 0.020194337743069977
# Time taken: 4.6151254336039225 min
# Dice similarity score is 0.00023778279622395834
# Processing image:  115924_013.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 3.580654782562403
# ITERATION: 2 Error Rate: 0.9614047289919831
# ITERATION: 3 Error Rate: 0.5314593053876232
# ITERATION: 4 Error Rate: 0.3547459391954717
# ITERATION: 5 Error Rate: 0.20362323709846064
# ITERATION: 6 Error Rate: 0.13449876195082824
# ITERATION: 7 Error Rate: 0.11497226799916879
# ITERATION: 8 Error Rate: 0.0935855899429114
# ITERATION: 9 Error Rate: 0.07360491095144643
# ITERATION: 10 Error Rate: 0.05784271713109357
# ITERATION: 11 Error Rate: 0.04738501852694916
# ITERATION: 12 Error Rate: 0.04065175186634619
# ITERATION: 13 Error Rate: 0.0357633863280141
# ITERATION: 14 Error Rate: 0.03320863835762312
# ITERATION: 15 Error Rate: 0.029991493322596534
# ITERATION: 16 Error Rate: 0.027695260906911198
# ITERATION: 17 Error Rate: 0.026478869305766154
# ITERATION: 18 Error Rate: 0.0244985367659635
# ITERATION: 19 Error Rate: 0.024480191150284446
# ITERATION: 20 Error Rate: 0.023953534539638627
# Time taken: 5.011747213204702 min
# Dice similarity score is 0.0015284220377604167
# Processing image:  118278_004.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 3.697481728367572
# ITERATION: 2 Error Rate: 0.9433709558229268
# ITERATION: 3 Error Rate: 0.5035404474077589
# ITERATION: 4 Error Rate: 0.19783894200373428
# ITERATION: 5 Error Rate: 0.08366941903184777
# ITERATION: 6 Error Rate: 0.047981911844774135
# ITERATION: 7 Error Rate: 0.037339062873123066
# ITERATION: 8 Error Rate: 0.03380344254959704
# ITERATION: 9 Error Rate: 0.03294776872612101
# ITERATION: 10 Error Rate: 0.03336381218193545
# ITERATION: 11 Error Rate: 0.03477729426333474
# ITERATION: 12 Error Rate: 0.034734565238361895
# ITERATION: 13 Error Rate: 0.032934195404754556
# ITERATION: 14 Error Rate: 0.029747915436035152
# ITERATION: 15 Error Rate: 0.025794784647831727
# ITERATION: 16 Error Rate: 0.022553740504977743
# ITERATION: 17 Error Rate: 0.020154558045967424
# ITERATION: 18 Error Rate: 0.01797559677422888
# ITERATION: 19 Error Rate: 0.01708385566457038
# ITERATION: 20 Error Rate: 0.016522594540232503
# Time taken: 3.6098748485247296 min
# Dice similarity score is 0.000232696533203125
# Processing image:  2_00400_sub0_006.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 3.7020499022035933
# ITERATION: 2 Error Rate: 0.9980490608902595
# ITERATION: 3 Error Rate: 0.5043553506696346
# ITERATION: 4 Error Rate: 0.26787544480772996
# ITERATION: 5 Error Rate: 0.1648775758111607
# ITERATION: 6 Error Rate: 0.1272707658564165
# ITERATION: 7 Error Rate: 0.10294731904280212
# ITERATION: 8 Error Rate: 0.07951975683735257
# ITERATION: 9 Error Rate: 0.06346359821877537
# ITERATION: 10 Error Rate: 0.05421067643327949
# ITERATION: 11 Error Rate: 0.046851145328005314
# ITERATION: 12 Error Rate: 0.04183990838841385
# ITERATION: 13 Error Rate: 0.038410336303279814
# ITERATION: 14 Error Rate: 0.03528478188984488
# ITERATION: 15 Error Rate: 0.032966973281512386
# ITERATION: 16 Error Rate: 0.03103251188180415
# ITERATION: 17 Error Rate: 0.029313409367592365
# ITERATION: 18 Error Rate: 0.02711091592898188
# ITERATION: 19 Error Rate: 0.02583410115323819
# ITERATION: 20 Error Rate: 0.02452415227558772
# Time taken: 3.3857930501302085 min
# Dice similarity score is 0.0
# Processing image:  116981_013.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 3.6816308574945635
# ITERATION: 2 Error Rate: 0.6720536893940435
# ITERATION: 3 Error Rate: 0.3799224385228159
# ITERATION: 4 Error Rate: 0.24281326403994236
# ITERATION: 5 Error Rate: 0.10696689685126246
# ITERATION: 6 Error Rate: 0.06450796271241327
# ITERATION: 7 Error Rate: 0.044591864784970354
# ITERATION: 8 Error Rate: 0.03315687562516495
# ITERATION: 9 Error Rate: 0.02728867661969947
# ITERATION: 10 Error Rate: 0.022766958535767746
# ITERATION: 11 Error Rate: 0.019785223090836024
# ITERATION: 12 Error Rate: 0.017862787429292627
# ITERATION: 13 Error Rate: 0.016648183202464216
# ITERATION: 14 Error Rate: 0.01575378717703189
# ITERATION: 15 Error Rate: 0.014921092095472106
# ITERATION: 16 Error Rate: 0.014940213942484917
# ITERATION: 17 Error Rate: 0.01445981730429218
# ITERATION: 18 Error Rate: 0.01386153314822662
# ITERATION: 19 Error Rate: 0.013796178046980254
# ITERATION: 20 Error Rate: 0.013511178447976361
# Time taken: 4.934641834100088 min
# Dice similarity score is 0.0007769266764322916
# Processing image:  118294_003.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 4.025923981394679
# ITERATION: 2 Error Rate: 0.8172370355227369
# ITERATION: 3 Error Rate: 0.3148402264391978
# ITERATION: 4 Error Rate: 0.16094677018347323
# ITERATION: 5 Error Rate: 0.0948293072889799
# ITERATION: 6 Error Rate: 0.07065685638203371
# ITERATION: 7 Error Rate: 0.05552788610944451
# ITERATION: 8 Error Rate: 0.04287385454979319
# ITERATION: 9 Error Rate: 0.03351613611512309
# ITERATION: 10 Error Rate: 0.027714288881966358
# ITERATION: 11 Error Rate: 0.023572266476072308
# ITERATION: 12 Error Rate: 0.019260529580015173
# ITERATION: 13 Error Rate: 0.01649395299040332
# ITERATION: 14 Error Rate: 0.014713556998257892
# ITERATION: 15 Error Rate: 0.013551766771068433
# ITERATION: 16 Error Rate: 0.01190257429241131
# ITERATION: 17 Error Rate: 0.010656103247120036
# ITERATION: 18 Error Rate: 0.009865689453151003
# ITERATION: 19 Error Rate: 0.009595162650007802
# ITERATION: 20 Error Rate: 0.009258266698637368
# Time taken: 4.2557673494021095 min
# Dice similarity score is 0.0017712910970052083
# Processing image:  118294_002.png
# Number of Clusters: 10
# ITERATION: 1 Error Rate: 3.326754446778097
# ITERATION: 2 Error Rate: 0.6870358112389914
# ITERATION: 3 Error Rate: 0.2669908649992011
# ITERATION: 4 Error Rate: 0.1703653256637657
# ITERATION: 5 Error Rate: 0.1324424617132567
# ITERATION: 6 Error Rate: 0.0970940341227053
# ITERATION: 7 Error Rate: 0.06306703656717179
# ITERATION: 8 Error Rate: 0.04432699213827039
# ITERATION: 9 Error Rate: 0.03321201522928161
# ITERATION: 10 Error Rate: 0.025388158798668455

# %%
##############################################################################
#Save result
    #import pdb;pdb.set_trace()
    with open('kmeans_dice.csv', 'w') as fp:
        fp.write(str(dice))
    with open('kmeans_time.csv', 'w') as fw:
        fw.write(str(time_cost))
##############################################################################
